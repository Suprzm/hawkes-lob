# %%
import sys
sys.path.insert(0, '..')

from src.hawkes_lob.hawkes import simulate_poisson, plot_poisson, simulate_hawkes, hawkes_intensity, plot_intensity

# %%
events = simulate_poisson(lambda_=10.0, T=50.0, seed=42)
print(f"Number of events : {len(events)}")
print(f"Expected (~λ*T)  : {10.0 * 50.0}")
# Out:
# Number of events : 499
# Expected (~λ*T)  : 500.0

# %%
plot_poisson(events, T=50.0, lambda_=10.0)

# %%
events = simulate_hawkes(mu=2.0, alpha=0.5, beta=1.0, T=50.0, seed=42)
print(f"Hawkes events : {len(events)}")

poisson_events = simulate_poisson(lambda_=2.0, T=50.0, seed=42)
print(f"Poisson events : {len(poisson_events)}")
# Out:
# Hawkes events : 183
# Poisson events : 112

# %%
plot_intensity(events, T=50.0, mu=2.0, alpha=0.5, beta=1.0)
